# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 609

# %%
cities
# Out:
# ['kodiak',
#  'okhotsk',
#  'bodaybo',
#  "nar'yan-mar",
#  'sabang',
#  'blackmans bay',
#  'bonthe',
#  'thompson',
#  'klaksvik',
#  'invercargill',
#  'grytviken',
#  'udachny',
#  'mangai',
#  'papatowai',
#  'new norfolk',
#  'longyearbyen',
#  'bukama',
#  'sisimiut',
#  'sao jose da coroa grande',
#  'petrove',
#  'college',
#  'north shore',
#  'yellowknife',
#  'lebu',
#  'tura',
#  'gonabad',
#  'olonkinbyen',
#  'utrik',
#  'dakhla',
#  'verdal',
#  'waitangi',
#  'road town',
#  'ushuaia',
#  'punta arenas',
#  'acara',
#  'bredasdorp',
#  'hawaiian paradise park',
#  'hede',
#  'adamstown',
#  'afaahiti',
#  'loshnitsa',
#  'uturoa',
#  'cenes de la vega',
#  'arraial do cabo',
#  'sola',
#  'bamboo flat',
#  'susuman',
#  'port-aux-francais',
#  'albany',
#  'chegdomyn',
#  'saint-philippe',
#  'puerto natales',
#  'mejit',
#  'kralendijk',
#  'port mathurin',
#  'pavlovskaya',
#  'port glaud',
#  'carauari',
#  "ytyk-kyuyel'",
#  'shalqar',
#  'douentza',
#  'gaspe',
#  'badger',
#  'qujing',
#  'kapuskasing',
#  'bera',
#  'chavusy',
#  'fale old settlement',
#  'west island',
#  'rongelap',
#  'ancud',
#  'kailua-kona',
#  'coquimbo',
#  'lihue',
#  'ke-macina',
#  'bethel',
#  'ghormach',
#  'porto novo',
#  'praia da vitoria',
#  'puerto rico',
#  'kisangani',
#  'isla del bosque',
#  "ha'il",
#  'mount isa',
#  'as sulayyil',
#  'christchurch',
#  'anadyr',
#  'wanxian',
#  'mettupalayam',
#  'acarau',
#  'qashyr',
#  'iskateley',
#  'peruibe',
#  'puerto deseado',
#  'katsuura',
#  'fredericia',
#  'wailua homesteads',
#  'taiohae',
#  'bursa',
#  'sao joao da barra',
#  'mount gambier',
#  'kingston',
#  'aasiaat',
#  'mukalla',
#  'ribeira grande',
#  'ocean shores',
#  'port lincoln',
#  'dhoraji',
#  'mascoutah',
#  'petropavlovsk-kamchatsky',
#  'tucuma',
#  'qaqortoq',
#  'coahuayana de hidalgo',
#  'gelemso',
#  'pervomayskoye',
#  'stanley',
#  'vera cruz',
#  'enewetak',
#  'igarka',
#  'dawei',
#  'cabo san lucas',
#  'xinyu',
#  'tyukalinsk',
#  'whitehorse',
#  'kibara',
#  'tolanaro',
#  'alotau',
#  'kayangel',
#  'tiksi',
#  'puerto san carlos',
#  'las khorey',
#  'greymouth',
#  'iqaluit',
#  'jayapura',
#  'edinburgh of the seven seas',
#  'hasaki',
#  'new martinsville',
#  'forster',
#  'ryotsu-minato',
#  'hermanus',
#  'uige',
#  'amga',
#  'taos',
#  'tiaret',
#  'es castell',
#  'dunedin',
#  'port elizabeth',
#  'la passe',
#  'togur',
#  'rincon de nicolas romero (cedros tercera manzana)',
#  'gassol',
#  'jamestown',
#  'whangarei',
#  'senador jose porfirio',
#  'puerto baquerizo moreno',
#  'san patricio',
#  'nogliki',
#  'vatutine',
#  'robore',
#  'dudinka',
#  'carepa',
#  'polyarnyye zori',
#  'ntossoni',
#  'oriximina',
#  'obigarm',
#  "'ohonua",
#  'barra de santo antonio',
#  'lianhe',
#  'kenai',
#  'sandnessjoen',
#  'colonia',
#  'antsiranana',
#  'tashtagol',
#  'vingt cinq',
#  'esmeraldas',
#  'nishinoomote',
#  'hamilton',
#  'isafjordur',
#  'makoua',
#  'thames',
#  'talnakh',
#  'tanout',
#  'mareeba',
#  'avarua',
#  'manokwari',
#  'vilyuchinsk',
#  'morinville',
#  'shingu',
#  'ilulissat',
#  'nemuro',
#  'gazojak',
#  'sarandi del yi',
#  'akureyri',
#  'corner brook',
#  'fereydunshahr',
#  'pailon',
#  'sitka',
#  'newman',
#  'port alfred',
#  'cuenca',
#  'egilsstadir',
#  'rockton',
#  'bilibino',
#  'khandud',
#  'buchanan',
#  'meadow lakes',
#  'galesong',
#  'vernon',
#  "arkhangel'sk",
#  'jamtara',
#  'walvis bay',
#  'ust-nera',
#  'miri',
#  'sao paulo de olivenca',
#  'bredy',
#  'constantia',
#  'axim',
#  'pirallahi',
#  'dongning',
#  'holualoa',
#  'chui',
#  'tinogasta',
#  'rikaze',
#  'sinabang',
#  'lloydminster',
#  'tam ky',
#  'namibe',
#  'vila velha',
#  'nereta',
#  'berezniki',
#  'usinsk',
#  'taroudant',
#  'antakotako',
#  'morehead city',
#  'ola',
#  'sao francisco do sul',
#  'borogontsy',
#  'cafayate',
#  'bratsk',
#  'saipan',
#  'happy valley-goose bay',
#  'fort st. john',
#  "'ain benian",
#  'okha',
#  'goba',
#  'dryden',
#  'palikir - national government center',
#  'tobruk',
#  'georgetown',
#  'gizo',
#  'nadi',
#  'mata-utu',
#  'hadagalli',
#  'keetmanshoop',
#  'kewanee',
#  'al mithnab',
#  'freetown',
#  'andrews',
#  'mezhdurechenskiy',
#  'vila franca do campo',
#  'magadan',
#  'punta cana',
#  'bingen am rhein',
#  'nova sintra',
#  'paraiso',
#  'al kharijah',
#  'ulladulla',
#  'hailar',
#  'hongjiang',
#  "cooper's town",
#  'fort stockton',
#  'el calafate',
#  'talara',
#  'conselheiro pena',
#  'al bawiti',
#  'linxia chengguanzhen',
#  'hirara',
#  'dickinson',
#  'lorengau',
#  'puerto ayora',
#  'minas de matahambre',
#  'kingscliff',
#  'george town',
#  'tuzantla',
#  'mahina',
#  'prince rupert',
#  'gwadar',
#  'richards bay',
#  'naracoorte',
#  'chonchi',
#  'kolonia town',
#  'alofi',
#  'juneau',
#  'basawul',
#  'chingirlau',
#  'gebeit',
#  'port sudan',
#  'songyang',
#  'brisas de zicatela',
#  'pisco',
#  'djebeniana',
#  'khandyga',
#  'weno',
#  'zaozersk',
#  'princeville',
#  'villa gesell',
#  'east london',
#  'ta`u',
#  'brokopondo',
#  'hithadhoo',
#  'cassilandia',
#  'bikenibeu village',
#  'kamaishi',
#  'korla',
#  'schweizer-reneke',
#  'agadez',
#  'karditsa',
#  'hami',
#  'touros',
#  'argo',
#  'arno',
#  'imphal',
#  'mahibadhoo',
#  'luderitz',
#  'remire-montjoly',
#  'gotha',
#  'ejura',
#  'coruripe',
#  'koungou',
#  'laguna',
#  'codrington',
#  'tamanrasset',
#  'awjilah',
#  'roma',
#  'curitibanos',
#  'bijelo polje',
#  'karkira',
#  'kosciuszko national park',
#  'atafu village',
#  'eyl',
#  'zhanaozen',
#  'laurel',
#  'petauke',
#  'coos bay',
#  'tazovsky',
#  'zhezqazghan',
#  'kimbe',
#  'kruisfontein',
#  'vilyuysk',
#  'san antonio',
#  'chopinzinho',
#  'ballina',
#  'porto seguro',
#  'kalifornsky',
#  'guiria',
#  'gurupa',
#  'kone',
#  'san julian',
#  'trstenik',
#  'sungai raya',
#  'yuzhno-kurilsk',
#  'rovaniemi',
#  'camacupa',
#  'qarazhal',
#  'irtyshsk',
#  'chagny',
#  'tsiombe',
#  'marsaskala',
#  'magdagachi',
#  'rio grande',
#  'gadzhiyevo',
#  'mar del plata',
#  'vorgashor',
#  'kyzylorda',
#  'kolonia',
#  'kourou',
#  'margaret river',
#  'reggane',
#  'qaryat suluq',
#  'bahia de caraquez',
#  'qianjiang',
#  'nikolayevsk-on-amure',
#  'angra do heroismo',
#  'kirakira',
#  'fortuna',
#  'solnechnyy',
#  'rosa zarate',
#  'niquero',
#  'yekaterinovka',
#  'kayenta',
#  'yauya',
#  'condado',
#  'ciudad lazaro cardenas',
#  'zouerate',
#  'tobelo',
#  'laojunmiao',
#  'south hedland',
#  'copiapo',
#  'klyuchi',
#  'tilcara',
#  'champerico',
#  'gunnedah',
#  'januaria',
#  'key west',
#  'selfoss',
#  'benghazi',
#  'dampit',
#  'novyy urengoy',
#  'barah',
#  'alice springs',
#  'itambacuri',
#  'mathis',
#  'fort bragg',
#  'carnarvon',
#  'ahau',
#  'kabinda',
#  'el alto',
#  'fuglafjordur',
#  'camalu',
#  'natal',
#  'saldanha',
#  'portland',
#  'bumba',
#  'bemidji',
#  'fuvahmulah',
#  'sorong',
#  'turpan',
#  'la tuque',
#  'union',
#  'keskin',
#  'bichura',
#  'lompoc',
#  'namdrik',
#  'fada',
#  'ngorongoro',
#  'gagarin',
#  'fort-shevchenko',
#  'san rafael',
#  'papao',
#  'san sebastian de la gomera',
#  'chita',
#  'la foa',
#  'vicksburg',
#  'ippy',
#  'ocos',
#  'trinidad',
#  'nantucket',
#  'pacanga',
#  'partenit',
#  'shimoda',
#  'patnanungan',
#  'el bauga',
#  'rapla',
#  'kyren',
#  'port moresby',
#  'carutapera',
#  'chernyshevskiy',
#  'skowhegan',
#  'acapulco de juarez',
#  'lionel town',
#  'palembang',
#  'fraserburgh',
#  'norfolk',
#  'skovorodino',
#  'flin flon',
#  'motta di livenza',
#  'eufaula',
#  'pattan',
#  'tekanpur',
#  'port-vila',
#  'cabedelo',
#  'bonnyville',
#  'parun',
#  'pont rouge',
#  'la ronge',
#  'anna',
#  'kidal',
#  'ugep',
#  'summerside',
#  'xai-xai',
#  'hammerfest',
#  'tafuna',
#  'island harbour',
#  "st. john's",
#  'kuanda',
#  'collingwood',
#  'saynshand',
#  'san antonio de pale',
#  'conception bay south',
#  'raymondville',
#  'rio gallegos',
#  'kish',
#  'iwaki',
#  'tocopilla',
#  'ondjiva',
#  'dudhi',
#  'geraldton',
#  'phan rang-thap cham',
#  'boyolangu',
#  'tagaw-bay',
#  'saint-denis',
#  'iquique',
#  'luena',
#  'tostado',
#  'buri ram',
#  'gumdag',
#  'itapirapua',
#  'celestun',
#  'tanki leendert',
#  'licheng',
#  'margate',
#  'ash shafa',
#  'kupang',
#  'leninogorsk',
#  'sitia',
#  'seogwipo',
#  'praia',
#  'bolton le sands',
#  'mogocha',
#  'trondheim',
#  "la'ie",
#  'motygino',
#  'boa vista',
#  'sinazongwe',
#  'puerto del rosario',
#  'isangel',
#  'fortaleza',
#  'alaghsas',
#  'ak-dovurak',
#  'kerikeri',
#  'bubaque',
#  'baikonur',
#  'inyonga',
#  'treinta y tres',
#  'saint-joseph',
#  'mount pearl',
#  'deqen',
#  'inarajan village',
#  'tadine',
#  'swift current',
#  'orapa',
#  'grenaa',
#  'alta',
#  'mugia',
#  'nema',
#  'port augusta',
#  'palmer',
#  "muzayri'",
#  'mendi',
#  'ocean city',
#  'lagos',
#  'pirae',
#  'mawu',
#  'kodinsk',
#  'goundam',
#  'aykhal',
#  'riyadh',
#  'al musayyib',
#  'spanish springs',
#  'sault ste. marie',
#  'kamloops',
#  'usogorsk',
#  'westport',
#  'bardai',
#  'whitby',
#  'santa vitoria do palmar',
#  'adzope',
#  'leyva solano',
#  'ronne',
#  'inari',
#  'williston',
#  'saint-francois',
#  'colesberg',
#  'vadso',
#  'shushi',
#  'mao',
#  'weihai',
#  'parkes',
#  'urangan',
#  'mancio lima',
#  'kardla',
#  'tranovaho',
#  'rockport',
#  'maturin',
#  'haiku-pauwela',
#  'sechura',
#  'mili',
#  'malvan',
#  'porbandar',
#  'zavetnoye',
#  'chambas',
#  'quellon',
#  'york',
#  'howrah',
#  'pariaman',
#  'miguel ahumada',
#  'sishilichengzi',
#  'parakou',
#  'kwale',
#  'shelby',
#  'tual',
#  'villa alberto andres alvarado aramburo',
#  'bonham',
#  'luwuk',
#  'mildura',
#  'tralee',
#  'daru',
#  'cargados carajos',
#  'pangody']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
units = "metric"
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | okhotsk
# Processing Record 3 of Set 1 | bodaybo
# Processing Record 4 of Set 1 | nar'yan-mar
# Processing Record 5 of Set 1 | sabang
# Processing Record 6 of Set 1 | blackmans bay
# Processing Record 7 of Set 1 | bonthe
# Processing Record 8 of Set 1 | thompson
# Processing Record 9 of Set 1 | klaksvik
# Processing Record 10 of Set 1 | invercargill
# Processing Record 11 of Set 1 | grytviken
# Processing Record 12 of Set 1 | udachny
# Processing Record 13 of Set 1 | mangai
# Processing Record 14 of Set 1 | papatowai
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | longyearbyen
# Processing Record 17 of Set 1 | bukama
# Processing Record 18 of Set 1 | sisimiut
# Processing Record 19 of Set 1 | sao jose da coroa grande
# Processing Record 20 of Set 1 | petrove
# Processing Record 21 of Set 1 | college
# Processing Record 22 of Set 1 | north shore
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | tura
# Processing Record 26 of Set 1 | gonabad
# Processing Record 27 of Set 1 | olonkinbyen
# Processing Record 28 of Set 1 | utrik
# Processing Record 29 of Set 1 | dakhla
# Processing Record 30 of Set 1 | verdal
# Processing Record 31 of Set 1 | waitangi
# Processing Record 32 of Set 1 | road town
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | acara
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | hawaiian paradise park
# Processing Record 38 of Set 1 | hede
# Processing Record 39 of Set 1 | adamstown
# Processing Record 40 of Set 1 | afaahiti
# Processing Record 41 of Set 1 | loshnitsa
# Processing Record 42 of Set 1 | uturoa
# Processing Record 43 of Set 1 | cenes de la vega
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | sola
# Processing Record 46 of Set 1 | bamboo flat
# Processing Record 47 of Set 1 | susuman
# Processing Record 48 of Set 1 | port-aux-francais
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | chegdomyn
# Processing Record 0 of Set 2 | saint-philippe
# Processing Record 1 of Set 2 | puerto natales
# Processing Record 2 of Set 2 | mejit
# Processing Record 3 of Set 2 | kralendijk
# Processing Record 4 of Set 2 | port mathurin
# Processing Record 5 of Set 2 | pavlovskaya
# Processing Record 6 of Set 2 | port glaud
# City not found. Skipping...
# Processing Record 7 of Set 2 | carauari
# Processing Record 8 of Set 2 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 9 of Set 2 | shalqar
# Processing Record 10 of Set 2 | douentza
# Processing Record 11 of Set 2 | gaspe
# Processing Record 12 of Set 2 | badger
# Processing Record 13 of Set 2 | qujing
# Processing Record 14 of Set 2 | kapuskasing
# Processing Record 15 of Set 2 | bera
# Processing Record 16 of Set 2 | chavusy
# Processing Record 17 of Set 2 | fale old settlement
# Processing Record 18 of Set 2 | west island
# Processing Record 19 of Set 2 | rongelap
# Processing Record 20 of Set 2 | ancud
# Processing Record 21 of Set 2 | kailua-kona
# Processing Record 22 of Set 2 | coquimbo
# Processing Record 23 of Set 2 | lihue
# Processing Record 24 of Set 2 | ke-macina
# Processing Record 25 of Set 2 | bethel
# Processing Record 26 of Set 2 | ghormach
# Processing Record 27 of Set 2 | porto novo
# Processing Record 28 of Set 2 | praia da vitoria
# Processing Record 29 of Set 2 | puerto rico
# Processing Record 30 of Set 2 | kisangani
# Processing Record 31 of Set 2 | isla del bosque
# Processing Record 32 of Set 2 | ha'il
# Processing Record 33 of Set 2 | mount isa
# Processing Record 34 of Set 2 | as sulayyil
# Processing Record 35 of Set 2 | christchurch
# Processing Record 36 of Set 2 | anadyr
# Processing Record 37 of Set 2 | wanxian
# Processing Record 38 of Set 2 | mettupalayam
# Processing Record 39 of Set 2 | acarau
# Processing Record 40 of Set 2 | qashyr
# Processing Record 41 of Set 2 | iskateley
# Processing Record 42 of Set 2 | peruibe
# Processing Record 43 of Set 2 | puerto deseado
# Processing Record 44 of Set 2 | katsuura
# Processing Record 45 of Set 2 | fredericia
# Processing Record 46 of Set 2 | wailua homesteads
# Processing Record 47 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 48 of Set 2 | bursa
# Processing Record 49 of Set 2 | sao joao da barra
# Processing Record 0 of Set 3 | mount gambier
# Processing Record 1 of Set 3 | kingston
# Processing Record 2 of Set 3 | aasiaat
# Processing Record 3 of Set 3 | mukalla
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | ocean shores
# Processing Record 6 of Set 3 | port lincoln
# Processing Record 7 of Set 3 | dhoraji
# Processing Record 8 of Set 3 | mascoutah
# Processing Record 9 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 10 of Set 3 | tucuma
# Processing Record 11 of Set 3 | qaqortoq
# Processing Record 12 of Set 3 | coahuayana de hidalgo
# Processing Record 13 of Set 3 | gelemso
# Processing Record 14 of Set 3 | pervomayskoye
# Processing Record 15 of Set 3 | stanley
# Processing Record 16 of Set 3 | vera cruz
# Processing Record 17 of Set 3 | enewetak
# Processing Record 18 of Set 3 | igarka
# Processing Record 19 of Set 3 | dawei
# Processing Record 20 of Set 3 | cabo san lucas
# Processing Record 21 of Set 3 | xinyu
# Processing Record 22 of Set 3 | tyukalinsk
# Processing Record 23 of Set 3 | whitehorse
# Processing Record 24 of Set 3 | kibara
# Processing Record 25 of Set 3 | tolanaro
# Processing Record 26 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 3 | kayangel
# Processing Record 28 of Set 3 | tiksi
# Processing Record 29 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 30 of Set 3 | las khorey
# Processing Record 31 of Set 3 | greymouth
# Processing Record 32 of Set 3 | iqaluit
# Processing Record 33 of Set 3 | jayapura
# Processing Record 34 of Set 3 | edinburgh of the seven seas
# Processing Record 35 of Set 3 | hasaki
# Processing Record 36 of Set 3 | new martinsville
# Processing Record 37 of Set 3 | forster
# Processing Record 38 of Set 3 | ryotsu-minato
# Processing Record 39 of Set 3 | hermanus
# Processing Record 40 of Set 3 | uige
# Processing Record 41 of Set 3 | amga
# Processing Record 42 of Set 3 | taos
# Processing Record 43 of Set 3 | tiaret
# Processing Record 44 of Set 3 | es castell
# Processing Record 45 of Set 3 | dunedin
# Processing Record 46 of Set 3 | port elizabeth
# Processing Record 47 of Set 3 | la passe
# Processing Record 48 of Set 3 | togur
# Processing Record 49 of Set 3 | rincon de nicolas romero (cedros tercera manzana)
# City not found. Skipping...
# Processing Record 0 of Set 4 | gassol
# Processing Record 1 of Set 4 | jamestown
# Processing Record 2 of Set 4 | whangarei
# Processing Record 3 of Set 4 | senador jose porfirio
# Processing Record 4 of Set 4 | puerto baquerizo moreno
# Processing Record 5 of Set 4 | san patricio
# Processing Record 6 of Set 4 | nogliki
# Processing Record 7 of Set 4 | vatutine
# Processing Record 8 of Set 4 | robore
# Processing Record 9 of Set 4 | dudinka
# Processing Record 10 of Set 4 | carepa
# Processing Record 11 of Set 4 | polyarnyye zori
# Processing Record 12 of Set 4 | ntossoni
# City not found. Skipping...
# Processing Record 13 of Set 4 | oriximina
# Processing Record 14 of Set 4 | obigarm
# Processing Record 15 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 16 of Set 4 | barra de santo antonio
# Processing Record 17 of Set 4 | lianhe
# Processing Record 18 of Set 4 | kenai
# Processing Record 19 of Set 4 | sandnessjoen
# Processing Record 20 of Set 4 | colonia
# Processing Record 21 of Set 4 | antsiranana
# Processing Record 22 of Set 4 | tashtagol
# Processing Record 23 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 24 of Set 4 | esmeraldas
# Processing Record 25 of Set 4 | nishinoomote
# Processing Record 26 of Set 4 | hamilton
# Processing Record 27 of Set 4 | isafjordur
# Processing Record 28 of Set 4 | makoua
# Processing Record 29 of Set 4 | thames
# Processing Record 30 of Set 4 | talnakh
# Processing Record 31 of Set 4 | tanout
# Processing Record 32 of Set 4 | mareeba
# Processing Record 33 of Set 4 | avarua
# Processing Record 34 of Set 4 | manokwari
# Processing Record 35 of Set 4 | vilyuchinsk
# Processing Record 36 of Set 4 | morinville
# Processing Record 37 of Set 4 | shingu
# Processing Record 38 of Set 4 | ilulissat
# Processing Record 39 of Set 4 | nemuro
# Processing Record 40 of Set 4 | gazojak
# Processing Record 41 of Set 4 | sarandi del yi
# Processing Record 42 of Set 4 | akureyri
# Processing Record 43 of Set 4 | corner brook
# Processing Record 44 of Set 4 | fereydunshahr
# Processing Record 45 of Set 4 | pailon
# Processing Record 46 of Set 4 | sitka
# Processing Record 47 of Set 4 | newman
# Processing Record 48 of Set 4 | port alfred
# Processing Record 49 of Set 4 | cuenca
# Processing Record 0 of Set 5 | egilsstadir
# Processing Record 1 of Set 5 | rockton
# Processing Record 2 of Set 5 | bilibino
# Processing Record 3 of Set 5 | khandud
# Processing Record 4 of Set 5 | buchanan
# Processing Record 5 of Set 5 | meadow lakes
# Processing Record 6 of Set 5 | galesong
# Processing Record 7 of Set 5 | vernon
# Processing Record 8 of Set 5 | arkhangel'sk
# Processing Record 9 of Set 5 | jamtara
# Processing Record 10 of Set 5 | walvis bay
# Processing Record 11 of Set 5 | ust-nera
# Processing Record 12 of Set 5 | miri
# Processing Record 13 of Set 5 | sao paulo de olivenca
# Processing Record 14 of Set 5 | bredy
# Processing Record 15 of Set 5 | constantia
# Processing Record 16 of Set 5 | axim
# Processing Record 17 of Set 5 | pirallahi
# Processing Record 18 of Set 5 | dongning
# Processing Record 19 of Set 5 | holualoa
# Processing Record 20 of Set 5 | chui
# Processing Record 21 of Set 5 | tinogasta
# Processing Record 22 of Set 5 | rikaze
# Processing Record 23 of Set 5 | sinabang
# Processing Record 24 of Set 5 | lloydminster
# Processing Record 25 of Set 5 | tam ky
# Processing Record 26 of Set 5 | namibe
# Processing Record 27 of Set 5 | vila velha
# Processing Record 28 of Set 5 | nereta
# City not found. Skipping...
# Processing Record 29 of Set 5 | berezniki
# Processing Record 30 of Set 5 | usinsk
# Processing Record 31 of Set 5 | taroudant
# Processing Record 32 of Set 5 | antakotako
# City not found. Skipping...
# Processing Record 33 of Set 5 | morehead city
# Processing Record 34 of Set 5 | ola
# Processing Record 35 of Set 5 | sao francisco do sul
# Processing Record 36 of Set 5 | borogontsy
# Processing Record 37 of Set 5 | cafayate
# Processing Record 38 of Set 5 | bratsk
# Processing Record 39 of Set 5 | saipan
# Processing Record 40 of Set 5 | happy valley-goose bay
# Processing Record 41 of Set 5 | fort st. john
# Processing Record 42 of Set 5 | 'ain benian
# Processing Record 43 of Set 5 | okha
# Processing Record 44 of Set 5 | goba
# Processing Record 45 of Set 5 | dryden
# Processing Record 46 of Set 5 | palikir - national government center
# Processing Record 47 of Set 5 | tobruk
# Processing Record 48 of Set 5 | georgetown
# Processing Record 49 of Set 5 | gizo
# Processing Record 0 of Set 6 | nadi
# Processing Record 1 of Set 6 | mata-utu
# Processing Record 2 of Set 6 | hadagalli
# Processing Record 3 of Set 6 | keetmanshoop
# Processing Record 4 of Set 6 | kewanee
# Processing Record 5 of Set 6 | al mithnab
# City not found. Skipping...
# Processing Record 6 of Set 6 | freetown
# Processing Record 7 of Set 6 | andrews
# Processing Record 8 of Set 6 | mezhdurechenskiy
# Processing Record 9 of Set 6 | vila franca do campo
# Processing Record 10 of Set 6 | magadan
# Processing Record 11 of Set 6 | punta cana
# Processing Record 12 of Set 6 | bingen am rhein
# Processing Record 13 of Set 6 | nova sintra
# Processing Record 14 of Set 6 | paraiso
# Processing Record 15 of Set 6 | al kharijah
# Processing Record 16 of Set 6 | ulladulla
# Processing Record 17 of Set 6 | hailar
# Processing Record 18 of Set 6 | hongjiang
# Processing Record 19 of Set 6 | cooper's town
# Processing Record 20 of Set 6 | fort stockton
# Processing Record 21 of Set 6 | el calafate
# Processing Record 22 of Set 6 | talara
# Processing Record 23 of Set 6 | conselheiro pena
# Processing Record 24 of Set 6 | al bawiti
# Processing Record 25 of Set 6 | linxia chengguanzhen
# Processing Record 26 of Set 6 | hirara
# Processing Record 27 of Set 6 | dickinson
# Processing Record 28 of Set 6 | lorengau
# Processing Record 29 of Set 6 | puerto ayora
# Processing Record 30 of Set 6 | minas de matahambre
# City not found. Skipping...
# Processing Record 31 of Set 6 | kingscliff
# Processing Record 32 of Set 6 | george town
# Processing Record 33 of Set 6 | tuzantla
# Processing Record 34 of Set 6 | mahina
# Processing Record 35 of Set 6 | prince rupert
# Processing Record 36 of Set 6 | gwadar
# Processing Record 37 of Set 6 | richards bay
# Processing Record 38 of Set 6 | naracoorte
# Processing Record 39 of Set 6 | chonchi
# Processing Record 40 of Set 6 | kolonia town
# Processing Record 41 of Set 6 | alofi
# Processing Record 42 of Set 6 | juneau
# Processing Record 43 of Set 6 | basawul
# Processing Record 44 of Set 6 | chingirlau
# Processing Record 45 of Set 6 | gebeit
# Processing Record 46 of Set 6 | port sudan
# Processing Record 47 of Set 6 | songyang
# Processing Record 48 of Set 6 | brisas de zicatela
# Processing Record 49 of Set 6 | pisco
# Processing Record 0 of Set 7 | djebeniana
# Processing Record 1 of Set 7 | khandyga
# Processing Record 2 of Set 7 | weno
# Processing Record 3 of Set 7 | zaozersk
# Processing Record 4 of Set 7 | princeville
# Processing Record 5 of Set 7 | villa gesell
# Processing Record 6 of Set 7 | east london
# Processing Record 7 of Set 7 | ta`u
# Processing Record 8 of Set 7 | brokopondo
# Processing Record 9 of Set 7 | hithadhoo
# Processing Record 10 of Set 7 | cassilandia
# Processing Record 11 of Set 7 | bikenibeu village
# Processing Record 12 of Set 7 | kamaishi
# Processing Record 13 of Set 7 | korla
# Processing Record 14 of Set 7 | schweizer-reneke
# Processing Record 15 of Set 7 | agadez
# Processing Record 16 of Set 7 | karditsa
# Processing Record 17 of Set 7 | hami
# Processing Record 18 of Set 7 | touros
# Processing Record 19 of Set 7 | argo
# Processing Record 20 of Set 7 | arno
# Processing Record 21 of Set 7 | imphal
# Processing Record 22 of Set 7 | mahibadhoo
# Processing Record 23 of Set 7 | luderitz
# Processing Record 24 of Set 7 | remire-montjoly
# Processing Record 25 of Set 7 | gotha
# Processing Record 26 of Set 7 | ejura
# Processing Record 27 of Set 7 | coruripe
# Processing Record 28 of Set 7 | koungou
# Processing Record 29 of Set 7 | laguna
# Processing Record 30 of Set 7 | codrington
# Processing Record 31 of Set 7 | tamanrasset
# Processing Record 32 of Set 7 | awjilah
# Processing Record 33 of Set 7 | roma
# Processing Record 34 of Set 7 | curitibanos
# Processing Record 35 of Set 7 | bijelo polje
# Processing Record 36 of Set 7 | karkira
# Processing Record 37 of Set 7 | kosciuszko national park
# City not found. Skipping...
# Processing Record 38 of Set 7 | atafu village
# Processing Record 39 of Set 7 | eyl
# Processing Record 40 of Set 7 | zhanaozen
# Processing Record 41 of Set 7 | laurel
# Processing Record 42 of Set 7 | petauke
# Processing Record 43 of Set 7 | coos bay
# Processing Record 44 of Set 7 | tazovsky
# Processing Record 45 of Set 7 | zhezqazghan
# Processing Record 46 of Set 7 | kimbe
# Processing Record 47 of Set 7 | kruisfontein
# Processing Record 48 of Set 7 | vilyuysk
# Processing Record 49 of Set 7 | san antonio
# Processing Record 0 of Set 8 | chopinzinho
# Processing Record 1 of Set 8 | ballina
# Processing Record 2 of Set 8 | porto seguro
# Processing Record 3 of Set 8 | kalifornsky
# Processing Record 4 of Set 8 | guiria
# City not found. Skipping...
# Processing Record 5 of Set 8 | gurupa
# Processing Record 6 of Set 8 | kone
# Processing Record 7 of Set 8 | san julian
# Processing Record 8 of Set 8 | trstenik
# Processing Record 9 of Set 8 | sungai raya
# Processing Record 10 of Set 8 | yuzhno-kurilsk
# Processing Record 11 of Set 8 | rovaniemi
# Processing Record 12 of Set 8 | camacupa
# Processing Record 13 of Set 8 | qarazhal
# Processing Record 14 of Set 8 | irtyshsk
# Processing Record 15 of Set 8 | chagny
# Processing Record 16 of Set 8 | tsiombe
# Processing Record 17 of Set 8 | marsaskala
# City not found. Skipping...
# Processing Record 18 of Set 8 | magdagachi
# Processing Record 19 of Set 8 | rio grande
# Processing Record 20 of Set 8 | gadzhiyevo
# Processing Record 21 of Set 8 | mar del plata
# Processing Record 22 of Set 8 | vorgashor
# Processing Record 23 of Set 8 | kyzylorda
# Processing Record 24 of Set 8 | kolonia
# Processing Record 25 of Set 8 | kourou
# Processing Record 26 of Set 8 | margaret river
# Processing Record 27 of Set 8 | reggane
# Processing Record 28 of Set 8 | qaryat suluq
# Processing Record 29 of Set 8 | bahia de caraquez
# Processing Record 30 of Set 8 | qianjiang
# Processing Record 31 of Set 8 | nikolayevsk-on-amure
# Processing Record 32 of Set 8 | angra do heroismo
# Processing Record 33 of Set 8 | kirakira
# Processing Record 34 of Set 8 | fortuna
# Processing Record 35 of Set 8 | solnechnyy
# Processing Record 36 of Set 8 | rosa zarate
# Processing Record 37 of Set 8 | niquero
# Processing Record 38 of Set 8 | yekaterinovka
# Processing Record 39 of Set 8 | kayenta
# Processing Record 40 of Set 8 | yauya
# Processing Record 41 of Set 8 | condado
# Processing Record 42 of Set 8 | ciudad lazaro cardenas
# Processing Record 43 of Set 8 | zouerate
# Processing Record 44 of Set 8 | tobelo
# Processing Record 45 of Set 8 | laojunmiao
# Processing Record 46 of Set 8 | south hedland
# Processing Record 47 of Set 8 | copiapo
# Processing Record 48 of Set 8 | klyuchi
# Processing Record 49 of Set 8 | tilcara
# Processing Record 0 of Set 9 | champerico
# Processing Record 1 of Set 9 | gunnedah
# Processing Record 2 of Set 9 | januaria
# Processing Record 3 of Set 9 | key west
# Processing Record 4 of Set 9 | selfoss
# Processing Record 5 of Set 9 | benghazi
# Processing Record 6 of Set 9 | dampit
# Processing Record 7 of Set 9 | novyy urengoy
# Processing Record 8 of Set 9 | barah
# Processing Record 9 of Set 9 | alice springs
# Processing Record 10 of Set 9 | itambacuri
# Processing Record 11 of Set 9 | mathis
# Processing Record 12 of Set 9 | fort bragg
# Processing Record 13 of Set 9 | carnarvon
# Processing Record 14 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 15 of Set 9 | kabinda
# Processing Record 16 of Set 9 | el alto
# Processing Record 17 of Set 9 | fuglafjordur
# Processing Record 18 of Set 9 | camalu
# Processing Record 19 of Set 9 | natal
# Processing Record 20 of Set 9 | saldanha
# Processing Record 21 of Set 9 | portland
# Processing Record 22 of Set 9 | bumba
# Processing Record 23 of Set 9 | bemidji
# Processing Record 24 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 25 of Set 9 | sorong
# Processing Record 26 of Set 9 | turpan
# Processing Record 27 of Set 9 | la tuque
# Processing Record 28 of Set 9 | union
# Processing Record 29 of Set 9 | keskin
# Processing Record 30 of Set 9 | bichura
# Processing Record 31 of Set 9 | lompoc
# Processing Record 32 of Set 9 | namdrik
# Processing Record 33 of Set 9 | fada
# Processing Record 34 of Set 9 | ngorongoro
# Processing Record 35 of Set 9 | gagarin
# Processing Record 36 of Set 9 | fort-shevchenko
# Processing Record 37 of Set 9 | san rafael
# Processing Record 38 of Set 9 | papao
# Processing Record 39 of Set 9 | san sebastian de la gomera
# Processing Record 40 of Set 9 | chita
# Processing Record 41 of Set 9 | la foa
# Processing Record 42 of Set 9 | vicksburg
# Processing Record 43 of Set 9 | ippy
# Processing Record 44 of Set 9 | ocos
# Processing Record 45 of Set 9 | trinidad
# Processing Record 46 of Set 9 | nantucket
# Processing Record 47 of Set 9 | pacanga
# Processing Record 48 of Set 9 | partenit
# Processing Record 49 of Set 9 | shimoda
# Processing Record 0 of Set 10 | patnanungan
# Processing Record 1 of Set 10 | el bauga
# Processing Record 2 of Set 10 | rapla
# Processing Record 3 of Set 10 | kyren
# Processing Record 4 of Set 10 | port moresby
# Processing Record 5 of Set 10 | carutapera
# Processing Record 6 of Set 10 | chernyshevskiy
# Processing Record 7 of Set 10 | skowhegan
# Processing Record 8 of Set 10 | acapulco de juarez
# Processing Record 9 of Set 10 | lionel town
# Processing Record 10 of Set 10 | palembang
# Processing Record 11 of Set 10 | fraserburgh
# Processing Record 12 of Set 10 | norfolk
# Processing Record 13 of Set 10 | skovorodino
# Processing Record 14 of Set 10 | flin flon
# Processing Record 15 of Set 10 | motta di livenza
# Processing Record 16 of Set 10 | eufaula
# Processing Record 17 of Set 10 | pattan
# Processing Record 18 of Set 10 | tekanpur
# Processing Record 19 of Set 10 | port-vila
# Processing Record 20 of Set 10 | cabedelo
# Processing Record 21 of Set 10 | bonnyville
# Processing Record 22 of Set 10 | parun
# Processing Record 23 of Set 10 | pont rouge
# Processing Record 24 of Set 10 | la ronge
# Processing Record 25 of Set 10 | anna
# Processing Record 26 of Set 10 | kidal
# Processing Record 27 of Set 10 | ugep
# Processing Record 28 of Set 10 | summerside
# Processing Record 29 of Set 10 | xai-xai
# Processing Record 30 of Set 10 | hammerfest
# Processing Record 31 of Set 10 | tafuna
# Processing Record 32 of Set 10 | island harbour
# Processing Record 33 of Set 10 | st. john's
# Processing Record 34 of Set 10 | kuanda
# Processing Record 35 of Set 10 | collingwood
# Processing Record 36 of Set 10 | saynshand
# Processing Record 37 of Set 10 | san antonio de pale
# Processing Record 38 of Set 10 | conception bay south
# Processing Record 39 of Set 10 | raymondville
# Processing Record 40 of Set 10 | rio gallegos
# Processing Record 41 of Set 10 | kish
# Processing Record 42 of Set 10 | iwaki
# Processing Record 43 of Set 10 | tocopilla
# Processing Record 44 of Set 10 | ondjiva
# Processing Record 45 of Set 10 | dudhi
# Processing Record 46 of Set 10 | geraldton
# Processing Record 47 of Set 10 | phan rang-thap cham
# Processing Record 48 of Set 10 | boyolangu
# Processing Record 49 of Set 10 | tagaw-bay
# Processing Record 0 of Set 11 | saint-denis
# Processing Record 1 of Set 11 | iquique
# Processing Record 2 of Set 11 | luena
# Processing Record 3 of Set 11 | tostado
# Processing Record 4 of Set 11 | buri ram
# Processing Record 5 of Set 11 | gumdag
# Processing Record 6 of Set 11 | itapirapua
# Processing Record 7 of Set 11 | celestun
# Processing Record 8 of Set 11 | tanki leendert
# City not found. Skipping...
# Processing Record 9 of Set 11 | licheng
# Processing Record 10 of Set 11 | margate
# Processing Record 11 of Set 11 | ash shafa
# City not found. Skipping...
# Processing Record 12 of Set 11 | kupang
# Processing Record 13 of Set 11 | leninogorsk
# Processing Record 14 of Set 11 | sitia
# Processing Record 15 of Set 11 | seogwipo
# City not found. Skipping...
# Processing Record 16 of Set 11 | praia
# Processing Record 17 of Set 11 | bolton le sands
# Processing Record 18 of Set 11 | mogocha
# Processing Record 19 of Set 11 | trondheim
# Processing Record 20 of Set 11 | la'ie
# Processing Record 21 of Set 11 | motygino
# Processing Record 22 of Set 11 | boa vista
# Processing Record 23 of Set 11 | sinazongwe
# Processing Record 24 of Set 11 | puerto del rosario
# Processing Record 25 of Set 11 | isangel
# Processing Record 26 of Set 11 | fortaleza
# Processing Record 27 of Set 11 | alaghsas
# Processing Record 28 of Set 11 | ak-dovurak
# Processing Record 29 of Set 11 | kerikeri
# Processing Record 30 of Set 11 | bubaque
# Processing Record 31 of Set 11 | baikonur
# Processing Record 32 of Set 11 | inyonga
# Processing Record 33 of Set 11 | treinta y tres
# Processing Record 34 of Set 11 | saint-joseph
# Processing Record 35 of Set 11 | mount pearl
# Processing Record 36 of Set 11 | deqen
# Processing Record 37 of Set 11 | inarajan village
# Processing Record 38 of Set 11 | tadine
# Processing Record 39 of Set 11 | swift current
# Processing Record 40 of Set 11 | orapa
# Processing Record 41 of Set 11 | grenaa
# Processing Record 42 of Set 11 | alta
# Processing Record 43 of Set 11 | mugia
# Processing Record 44 of Set 11 | nema
# Processing Record 45 of Set 11 | port augusta
# Processing Record 46 of Set 11 | palmer
# Processing Record 47 of Set 11 | muzayri'
# City not found. Skipping...
# Processing Record 48 of Set 11 | mendi
# Processing Record 49 of Set 11 | ocean city
# Processing Record 0 of Set 12 | lagos
# Processing Record 1 of Set 12 | pirae
# Processing Record 2 of Set 12 | mawu
# Processing Record 3 of Set 12 | kodinsk
# Processing Record 4 of Set 12 | goundam
# Processing Record 5 of Set 12 | aykhal
# Processing Record 6 of Set 12 | riyadh
# Processing Record 7 of Set 12 | al musayyib
# Processing Record 8 of Set 12 | spanish springs
# Processing Record 9 of Set 12 | sault ste. marie
# Processing Record 10 of Set 12 | kamloops
# Processing Record 11 of Set 12 | usogorsk
# Processing Record 12 of Set 12 | westport
# Processing Record 13 of Set 12 | bardai
# Processing Record 14 of Set 12 | whitby
# Processing Record 15 of Set 12 | santa vitoria do palmar
# Processing Record 16 of Set 12 | adzope
# Processing Record 17 of Set 12 | leyva solano
# Processing Record 18 of Set 12 | ronne
# Processing Record 19 of Set 12 | inari
# Processing Record 20 of Set 12 | williston
# Processing Record 21 of Set 12 | saint-francois
# Processing Record 22 of Set 12 | colesberg
# Processing Record 23 of Set 12 | vadso
# Processing Record 24 of Set 12 | shushi
# Processing Record 25 of Set 12 | mao
# Processing Record 26 of Set 12 | weihai
# Processing Record 27 of Set 12 | parkes
# Processing Record 28 of Set 12 | urangan
# Processing Record 29 of Set 12 | mancio lima
# Processing Record 30 of Set 12 | kardla
# Processing Record 31 of Set 12 | tranovaho
# City not found. Skipping...
# Processing Record 32 of Set 12 | rockport
# Processing Record 33 of Set 12 | maturin
# Processing Record 34 of Set 12 | haiku-pauwela
# Processing Record 35 of Set 12 | sechura
# Processing Record 36 of Set 12 | mili
# Processing Record 37 of Set 12 | malvan
# Processing Record 38 of Set 12 | porbandar
# Processing Record 39 of Set 12 | zavetnoye
# Processing Record 40 of Set 12 | chambas
# Processing Record 41 of Set 12 | quellon
# Processing Record 42 of Set 12 | york
# Processing Record 43 of Set 12 | howrah
# Processing Record 44 of Set 12 | pariaman
# Processing Record 45 of Set 12 | miguel ahumada
# Processing Record 46 of Set 12 | sishilichengzi
# City not found. Skipping...
# Processing Record 47 of Set 12 | parakou
# Processing Record 48 of Set 12 | kwale
# Processing Record 49 of Set 12 | shelby
# Processing Record 0 of Set 13 | tual
# Processing Record 1 of Set 13 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 2 of Set 13 | bonham
# Processing Record 3 of Set 13 | luwuk
# Processing Record 4 of Set 13 | mildura
# Processing Record 5 of Set 13 | tralee
# Processing Record 6 of Set 13 | daru
# Processing Record 7 of Set 13 | cargados carajos
# City not found. Skipping...
# Processing Record 8 of Set 13 | pangody
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          583
# Lat           583
# Lng           583
# Max Temp      583
# Humidity      583
# Cloudiness    583
# Wind Speed    583
# Country       583
# Date          583
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       kodiak  57.7900 -152.4072      5.73        93         100        5.14
# 1      okhotsk  59.3833  143.3000      5.83        71           7        1.47
# 2      bodaybo  57.8506  114.1933     10.38        79          77        0.84
# 3  nar'yan-mar  67.6713   53.0870     -2.10        90          98        4.89
# 4       sabang   5.8933   95.3214     28.59        69         100        5.61
#
#   Country        Date
# 0      US  1683679211
# 1      RU  1683679211
# 2      RU  1683679211
# 3      RU  1683679211
# 4      ID  1683679212

# %%
# Export the City_Data into a csv
city_data_df.to_csv("./output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("./output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            montbrison  45.6667    4.0833     12.19        85          99
# 1            carutapera  -1.1950  -46.0200     24.48        92          50
# 2                 tiksi  71.6872  128.8694     -4.43        70          88
# 3              islamkot  24.6997   70.1770     38.36        16           0
# 4        puerto natales -51.7236  -72.4875      3.43        84          13
#
#          Wind Speed Country        Date
# City_ID
# 0              1.00      FR  1683612655
# 1              1.40      BR  1683612655
# 2              8.85      RU  1683612186
# 3              5.25      PK  1683612656
# 4              2.05      CL  1683612181

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o",edgecolor='black')

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2023-05-09)")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("./output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o",edgecolor='black')

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Humidity (2023-05-09)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("./output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o",edgecolor='black')

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Cloudiness (2023-05-09)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("./output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o",edgecolor='black')

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Wind Speed (2023-05-09)")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("./output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = -0.12x +21.0

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
filtr_north = city_data_df['Lat']>=0
northern_hemi_df = city_data_df[filtr_north]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        montbrison  45.6667    4.0833     12.19        85          99
# 2             tiksi  71.6872  128.8694     -4.43        70          88
# 3          islamkot  24.6997   70.1770     38.36        16           0
# 6           kirensk  57.7853  108.1119     20.05        45           9
# 7            alavus  62.5833   23.6167      9.21        54         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.00      FR  1683612655
# 2              8.85      RU  1683612186
# 3              5.25      PK  1683612656
# 6              5.61      RU  1683612656
# 7              4.09      FI  1683612656

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
filtr_south = city_data_df['Lat']<0
southern_hemi_df = city_data_df[filtr_south]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1               carutapera  -1.1950  -46.0200     24.48        92          50
# 4           puerto natales -51.7236  -72.4875      3.43        84          13
# 5             port lincoln -34.7333  135.8667     16.19        64          92
# 11       port-aux-francais -49.3500   70.2167      6.63        94          87
# 12                waitangi -43.9535 -176.5597     15.46        93          99
#
#          Wind Speed Country        Date
# City_ID
# 1              1.40      BR  1683612655
# 4              2.05      CL  1683612181
# 5              4.70      AU  1683612263
# 11             6.51      TF  1683612188
# 12             4.47      NZ  1683612185

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(5,-5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.6446956332926994

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.564714939108854

# %% [markdown]
# **Discussion about the linear relationship:** We see a linear relationship between the dependant (Max Temp) and the independant variable (Latitude). In this case we can see that the closer to the Ecuador the tmeperature tends to increase

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Hummidity')
plt.annotate(line_eq,(50,10),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.002195080522545154

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.005799320904223842

# %% [markdown]
# **Discussion about the linear relationship:** We see a clear NON linear relationship between the dependant (Humidity) and the independant variable (Latitude) Thus we cannont interpretate meaningfully a correlation between the two varibles

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(50,20),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.00348566261698662

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(-55,30),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.0076532083043005525

# %% [markdown]
# **Discussion about the linear relationship:** We see a clear NON linear relationship between the dependant (Cloudiness) and the independant variable (Latitude) Thus we cannont interpretate meaningfully a correlation between the two varibles

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(5,12),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.008677492659344269

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(-50,8),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.0540028213712354

# %% [markdown]
# **Discussion about the linear relationship:** We see a clear NON linear relationship between the dependant (Wind Speed) and the independant variable (Latitude) Thus we cannont interpretate meaningfully a correlation between the two varibles
